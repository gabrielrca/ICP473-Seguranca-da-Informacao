# %%
frase="the snow lay thick on the steps and the snowflakes driven by the wind looked black in the headlights of the cars"
resultado = ""
letras_vistas = set()

for letra in frase:
    if letra != " " and letra not in letras_vistas:
        resultado += letra
        letras_vistas.add(letra)


print(resultado)
# Out:
# thesnowlayickpdfrvbg

# %%
alfabeto = "abcdefghijklmnopqrstuvwxyz"
for letra in alfabeto:
    if letra not in letras_vistas:
        resultado += letra

print(resultado)
# Out:
# thesnowlayickpdfrvbgjmquxz

# %%
print("alfabeto: " + alfabeto)
print("resultad: "+ resultado)
# Out:
# alfabeto: abcdefghijklmnopqrstuvwxyz
# resultad: thesnowlayickpdfrvbgjmquxz

# %%
for i in range(len(alfabeto)):
    mapa_decodificacao[alfabeto[i]] = resultado[i]

# %%
print(mapa_decodificacao)
# Out:
# {'a': 't', 'b': 'h', 'c': 'e', 'd': 's', 'e': 'n', 'f': 'o', 'g': 'w', 'h': 'l', 'i': 'a', 'j': 'y', 'k': 'i', 'l': 'c', 'm': 'k', 'n': 'p', 'o': 'd', 'p': 'f', 'q': 'r', 'r': 'v', 's': 'b', 't': 'g', 'u': 'j', 'v': 'm', 'w': 'q', 'x': 'u', 'y': 'x', 'z': 'z'}

# %%
mensagem_codificada = "SIdKHKdMafHCrKIaBIeSHIMCKdlfeaIla".lower()
mensagem_decodificada = ""
for letra in mensagem_codificada:
    mensagem_decodificada += mapa_decodificacao[letra] 

print(mensagem_decodificada)
# Out:
# basilisktoleviathanblakeiscontact
